# %%
# Required Packages
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %%
# Define the data
X = [1,2,3,4,5]
Y = [100,200,150,300,250]

# %%
# Create a basic line chart
plt.plot(X,Y)
plt.title('Basic Line Chart')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %%
# There are different style for a single chart to represent it
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.rcdefaults()
# Define the data
X = [1,2,3,4,5]
Y = [100,200,150,300,250]

# Create a basic line chart
plt.plot(X,Y)
plt.title("Basic Line Chart")
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %%
# Creating a Line Chart using Marker
plt.plot(X,Y, marker = '>') 
# plt.plot(X,Y, marker = 'o')
plt.title("Basic Line Chart")
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %%
# Create a linechart with different line styles
plt.plot(X,Y, '-o', color = 'red', linewidth =2, label = 'Line-1')
plt.plot(X, [200,230,250,200,150], '--',color='blue',linewidth = 4, label ='Line-2')
plt.title('Line Chart with Different line styles')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
pth = r"D:\Data Visualization using Python\Monthly_Sales_Profit_Dataset.xlsx"
sales = pd.read_excel(pth,sheet_name='Monthly Sales & Profit')

# %%
sales.head()
# Out:
#       Month   Sales  Profit
# 0   January  120000   25000
# 1  February  135000   30000
# 2     March  150000   35000
# 3     April  145000   32000
# 4       May  160000   40000

# %%
# Combination of column Chart and Line Chart using Sales and Profit
fig, ax = plt.subplots(figsize = (10,3))
ax.bar(sales['Month'],sales['Sales'], color = 'darkblue', label ="Sales")
ax.plot(sales['Month'], sales['Profit'], color = 'red', label = "Profit")

ax.set_xlabel('Month')
ax.set_ylabel('Amount (in USD)')
ax.legend(loc = 'upper left')
plt.show()

# %%
import warnings
warnings.filterwarnings
# Out:
# <function warnings.filterwarnings(action, message='', category=<class 'Warning'>, module='', lineno=0, append=False)>

# %%
# Sales as the column chart and Quantity and profit as line chart
sales = [100,200,300,400,500]
quantity = [10,20,30,40,50]
profit = [90,160,210,280,400]

plt.style.use("fivethirtyeight")

fig,ax = plt.subplots(figsize = (10,4))
ax.bar(np.arange(len(sales)),sales,align='center')

# plot the line chart for quantity
ax.plot(np.arange(len(quantity)), quantity,color = 'red', linestyle ='dashed')

# plot the line chart for profit
ax.plot(np.arange(len(profit)),profit,color = 'orange',linestyle = 'dotted')

# Adding label and notations
ax.set_xlabel('Month')
ax.set_ylabel('Value')
ax.set_xticks(np.arange(len(sales)))
ax.set_xticklabels(['Jan','Feb','Mar','Apr','May'])
ax.legend(['Quantity','Profit'])

# Adding a data labels
for i, v in enumerate(sales):
    ax.text(i,v, str(v), ha = 'center', va = 'bottom')
plt.show()

# %%
target = 1000
sales = [920,900,110,1050,890,1090,950,1020]
plt.plot([target] * len(sales),label = 'Target')
plt.plot(sales, label = 'Sales')
plt.legend()
plt.xlabel("Month")
plt.ylabel("Amount")
plt.title("Target vs Sales")
plt.show()

# %%
lc1 = pd.read_excel(pth,sheet_name='Monthly Sales & Profit')

# %%
lc1.head()
# Out:
#       Month   Sales  Profit
# 0   January  120000   25000
# 1  February  135000   30000
# 2     March  150000   35000
# 3     April  145000   32000
# 4       May  160000   40000

# %%
fig,ax = plt.subplots(figsize = (10,4))
ax.plot(lc1['Month'],lc1['Sales'], color ='blue',marker ='o',markersize = 6,label ='Sales')


ax.set_title("Sales by Month")
ax.set_xlabel('Month')
ax.set_ylabel('Sales')
ax.set_ylabel('Sales')
ax.legend()
plt.xticks(rotation = 45)
plt.show()

# %%
# Creating mutiple line chart
lc2 = pd.read_excel(pth, sheet_name = "Monthly Sales & Profit")

# %%
lc2.head()
# Out:
#       Month   Sales  Profit
# 0   January  120000   25000
# 1  February  135000   30000
# 2     March  150000   35000
# 3     April  145000   32000
# 4       May  160000   40000

# %%
fig, ax = plt.subplots(figsize=(12,4))
ax.plot(lc2.Month,lc2.Sales,linewidth= 2, color ='red',marker='o',markersize = 6,label='Sales')
ax.plot(lc2.Month,lc2.Profit,linewidth=2,color='blue',marker='>',markersize=6,label='Profit')

ax.set_title("Monthly Sales & Profit")
ax.set_xlabel('Month')
ax.set_ylabel('Sales')

plt.xticks(rotation = 45)
ax.legend(loc = 'lower left',fontsize = 10)
plt.show()

# %%
pth1=r"D:\Data Visualization using Python\Monthly_Sales_Data.xlsx"

# %%
lc3 = pd.read_excel(pth1,sheet_name="Sales Data")

# %%
lc3.head(2)
# Out:
#   Month  UnitsSold  TotalTransaction
# 0   Jan        120              1400
# 1   Feb        200              1800

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
month =lc3.Month
unitSold =lc3.UnitsSold
total_transaction = lc3.TotalTransaction
 # Create figure and axis object
fig,ax =plt.subplots(figsize=(20,7))
plt.style.use('seaborn-v0_8')

ax.bar(month,total_transaction,align='center',color='darkblue',edgecolor='white',label = 'Total Transaction')
ax.set_ylabel('Total Transaction',color ='darkblue')
ax.tick_params(axis='y',labelcolor = 'darkblue')

# Change Axis

ax1 = ax.twinx()
ax1.plot(month,unitSold,color = 'red',linewidth = 4,label ="Units Sold")
ax1.set_ylabel('Units Sold',color='red')
ax1.tick_params(axis='y',labelcolor='red')

for i,v in enumerate(unitSold):
    ax1.text(i,v,str(v),color='red',ha='center',va = "bottom",fontsize = "x-large")

ax.legend(loc ='upper left')
ax1.legend(loc = 'upper right')
plt.show()
